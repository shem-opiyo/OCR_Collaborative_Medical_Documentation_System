# %% [markdown]
# ### A simulation of a server environment in terms of loading models and single requests

# %%
# Let's initialze our libraries first
import os, subprocess
import numpy as np
import datetime

import ffmpeg

import torch, torchaudio, spacy
from sklearn.cluster import AgglomerativeClustering

# %%
# Then the models
# ----- Denoising
from denoiser import pretrained
from denoiser.dsp import convert_audio
# ------ Voice transcription
from faster_whisper import WhisperModel
# ------ Speaker diarization
from speechbrain.inference.speaker import EncoderClassifier
from transformers import AutoTokenizer, AutoModelForSequenceClassification
# ------ Grammar correction
from happytransformer import HappyTextToText, TTSettings

# %%
# Then load some of the models

# ----- Denoising model
denoising_model = pretrained.dns64()

# ----- Voice transcription model
transcription_model = WhisperModel("tiny")

# ----- Dirization model
speech_dairization_model_path = "pretrained_models/spkrec-xvect-voxceleb"
speech_dairization_classifier = EncoderClassifier.from_hparams(
    source=speech_dairization_model_path,
    run_opts={"device": "cpu"}     # or "cuda" if you have a GPU
)

# ----- Text classification model
text_classification_model_path = "self_trained_models/nlpie-distil-clinicalbert-0.66"
text_classification_model = AutoModelForSequenceClassification.from_pretrained(text_classification_model_path)
text_classification_tokenizer = AutoTokenizer.from_pretrained(text_classification_model_path)

# ----- Entity extraction model
entity_extraction_model_path = "pretrained_models/en_core_med7_lg"
entity_extraction_model = spacy.load("entity_extraction_model_path")

# ----- Grammar correction model
grammar_correction_model_name = "vennify/t5-base-grammar-correction"
grammar_correction_model = HappyTextToText("T5",  grammar_correction_model_name)

# %% [markdown]
# Step 1 - Audio input
#     Let's assume the frontend already chunks the voice input and sends over bits of audio files

# %%
audio_file_path = "C:/Users/HP/Desktop/assignments/Final _Year/test_audio/sample_interview(1).mp3"
request_number = 1

# %% [markdown]
# Step 2 - Audio preprocessing

# %%
# Audio format modification
def verify_format(audio_file_path):
    if not os.path.exists(audio_file_path):
        print(f"Error: File not found at {audio_file_path}")
        return None

    if audio_file_path.lower().endswith(".wav"):
        print(f"File is already a WAV: {audio_file_path}")
        return audio_file_path

    # Construct the output WAV file path
    wav_file = os.path.splitext(audio_file_path)[0] + ".wav"

    # Check if the output directory exists
    output_dir = os.path.dirname(wav_file)
    if output_dir and not os.path.exists(output_dir):
        try:
            os.makedirs(output_dir)
        except OSError as e:
            print(f"Error creating output directory: {e}")
            return None

    try:
        # Use ffmpeg-python for the conversion
        ffmpeg.input(audio_file_path).output(wav_file).run(quiet=True)
        print(f"Successfully converted {audio_file_path} to {wav_file}")
        return wav_file
    
    except ffmpeg.Error as e:
        print(f"Error converting {audio_file_path} to WAV:")
        print(e.stderr.decode())  # Print the ffmpeg error message
        return None
    
    except FileNotFoundError:
        print("Error: ffmpeg not found. Please ensure ffmpeg is installed and in your system's PATH.")
        return None
    
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

audio_file_path = verify_format( audio_file_path)
# Out:
# Successfully converted C:/Users/HP/Desktop/assignments/Final _Year/test_audio/sample_interview(1).mp3 to C:/Users/HP/Desktop/assignments/Final _Year/test_audio/sample_interview(1).wav

# %%
# Denoising audio file
print(f"Denoising audio - {audio_file_path} - request : {request_number}")
wav, sr = torchaudio.load(audio_file_path)
wav = convert_audio(wav, sr, denoising_model.sample_rate, denoising_model.chin)
with torch.no_grad():
    denoised = denoising_model(wav[None])[0]
    torchaudio.save(f'test_audio/denoised_no_{request_number}_{audio_file_path[:-3]}.wav', denoised, denoising_model.sample_rate)

audio_file_path = f'test_audio/denoised_no_{request_number}_{audio_file_path[:-3]}.wav'
# Out:
# Denoising audio - C:/Users/HP/Desktop/assignments/Final _Year/test_audio/sample_interview(1).wav - request : 1

# %%
# Step 3 - Audio Transcription
segments, _ = transcription_model.transcribe(audio_file_path)
transcript = ""
time_segments = []
for segment in segments:
    print(segment.text)
    transcript += segment.text[1:] + "\n"
    time_segments.append({"start": segment.start, "end": segment.end, "text": segment.text[1:]})

print(transcript)
# Out:
#  Man, what's that with me?
#  Yes.
#  Hi.
#  Here's, I'll be your doctor today.
#  I'm going to just wash my hands really quick.
#  Would you perform this stone here?
#  Oh, you can.
#  Pat's fine.
#  Great.
#  Well, it's nice to meet you.
#  Can you tell me why you're here today?
#  I have a terrible headache.
#  It looks really bad.
#  Is there anything else besides your headache that you want to address here
#  today at the clinical point?
#  No.
#  It's just that.
#  Except I am concerned.
#  I just recently changed insurance companies and I'm not sure this is going
#  to be covered yet.
#  What we can do is, well, we're talking and I'm doing your history
#  and physical.
#  I will have my office secretary look and do the insurance
#  plane that you're gas.
#  So you don't have to worry about that.
#  That sounds good.
#  Okay.
#  Sounds great.
#  Anything else?
#  No.
#  I just, this is just really bad.
#  Okay.
#  So what I'd like to do today, and let's take a look at what's causing
#  your headache.
#  All right.
#  I will go over history, physical.
#  And then we'll do our physical exam.
#  And then we will look into your insurance policy and make sure that's all.
#  Okay.
#  You know, 10 cares.
#  That sounds good.
#  Yeah.
#  That's good.
#  Perfect.
#  So tell me a little bit more about this.
#  The head pain that you're having.
#  Well, it started about three days ago and nothing has helped.
#  It's, it's just laid me flat.
#  I haven't been able to go to work.
#  It's, um, nothing's helped.
#  I, um, it's, it's all over.
#  Um, I, it really bad when I move.
#  So I'm trying not to move too much.
#  And the light is bothering me a lot.
#  Okay.
#  Um, and then, fortunately, I can't dim the lights in this room.
#  Okay.
#  But it's okay.
#  I'll try to go quickly and, um, we'd be okay if I took some notes.
#  Sure.
#  All right.
#  So you said this headache started about three days ago.
#  Okay.
#  Um, was there any, um, anything that brought about anything unusual?
#  What happened maybe three days ago?
#  Really?
#  No.
#  Okay.
#  Um, can you tell me anything that makes it better?
#  There's no nothings made it better.
#  I took some Tylenol and tried to moatrin, nothing.
#  Um, I just try not to move too much.
#  All right.
#  Um, was there anything that makes it worse?
#  Yeah.
#  Like movement and light.
#  Okay.
#  And, um, it's just constant though.
#  There's, you know, it doesn't, it's just constant.
#  It's, it's all over.
#  Okay.
#  Um, so if you had to rate a pain scale, um, zero being no pain,
#  ten being the worst pain you ever had.
#  Yeah.
#  It's a ten.
#  I've never had a headache like this.
#  Okay.
#  Yeah.
#  That sounds really bad.
#  Um, now as far as radiation does it move?
#  Does it, you said the head, the pain is all up there for your head?
#  It's kind of all over.
#  Okay.
#  Um, but it also, I've got this shooting pain down my neck.
#  And my neck is, is very stiff.
#  Okay.
#  Um, but you need to not, it's, it's, it's the entire head.
#  Okay.
#  Yeah.
#  Um, as far as in the, in the timing, you said that started three days ago, but you said
#  it's a constant.
#  Yeah.
#  It, it, it, it started gradually, but once, once it got there, it's, it hasn't gone away.
#  It doesn't get better.
#  It doesn't get worse.
#  It's just the same.
#  Okay.
#  Um, so do you, yeah.
#  What I want to get is your perception of what you think is going on.
#  Oh, I don't know.
#  I just, I can hardly think it's so painful.
#  I, I just, um, because it's so bad.
#  I was afraid, um, my neighbor, um, had a headache and ignored it last year.
#  And, uh, suddenly started having seizures and it turns out he had a, um, a brain tumor.
#  So I thought, I, I just should come in and, you know, I can understand your
#  concern.
#  Um, what, how is it impacting your daily life?
#  I can't go to work.
#  Okay.
#  I can't do anything.
#  Yeah.
#  Okay.
#  So it sounds like it's really impacting your life.
#  Yeah.
#  Yeah.
#  Okay.
#  Um, if it's okay, I would like to go some talk about a little bit about your medical
#  history or social history.
#  All right.
#  Um, can you tell me as first your medical history, have, do you have any medical conditions
#  I should be aware of?
#  Um, uh, that not, uh, I was diagnosed with a high blood pressure about three years ago.
#  But, uh, we've been addressing it with diet changes since it's controlled.
#  It's been monitored?
#  Yeah.
#  I go in usually I had been just in it's been well controlled.
#  So, okay.
#  I haven't been on medication for that other than that.
#  I haven't had any problems.
#  Okay, any surgical history in the hospitalizations?
#  No.
#  All right.
#  And you said you're only medicine you're taking was the talent
#  of all trades.
#  Yeah, and they didn't help.
#  Yeah, okay.
#  I just wanted to verify.
#  Do you have any drug allergies?
#  No.
#  No.
#  Okay.
#  What about family history?
#  Do you have any medical history of headaches or...
#  In my family?
#  Right.
#  Oh, you know, my mom said she used to get my green
#  and when she was in her 20s and 30s.
#  Okay.
#  But I don't remember her saying anything else about it.
#  My sister, I've one sister.
#  She's healthy.
#  My dad, he has a high blood pressure
#  rather than that.
#  He's healthy.
#  That's about it.
#  I don't have any kit.
#  All right.
#  It's all right.
#  I would like to ask you some social history questions
#  that just for the records.
#  Do you smoke?
#  Yeah, I do.
#  Is it cigarettes or children?
#  Yes, it's okay.
#  How much do you smoke?
#  About a half a pack a day.
#  Okay.
#  What about alcohol?
#  I don't drink.
#  Okay.
#  Also, are you married?
#  Yeah, I'm married.
#  Okay.
#  And children?
#  No.
#  Okay.
#  And just some just some additional questions is...
#  Looking at kind of G. Wayne history,
#  are you last menstrual period?
#  Oh, I'm in a menopause.
#  Okay.
#  So, going back into the history again, have you...
#  You said your mom had migraines earlier on.
#  Have you been around and you know other...
#  You haven't been nauseous or have you been...
#  Yeah, I've been nauseous.
#  Okay.
#  That night, I threw up twice early on.
#  Okay.
#  Because when I move, it makes me nauseous.
#  Okay.
#  Nothing of the ordinary or the past couple weeks have you been on any trips or anything?
#  Or...
#  Actually, a week ago I was in North Carolina for a family reunion.
#  Okay.
#  And there was a four-year-old who was sick there.
#  I don't know what they had.
#  But I guess they ended up taking into emergency.
#  So, let me just...
#  So, Marisa, make sure I've got everything straight so far.
#  You started in the onset of a severe headache about three days ago.
#  It's worse with movement.
#  Yeah.
#  Light really makes a hurt bad.
#  It's a 10 out of 10 pain.
#  And you're also complaining of a stiff neck with that.
#  Yes.
#  It came on gradually.
#  It's been constant pain in the frontal area.
#  Medical history here in Hayper.
#  You have high blood pressure, but that's control of the diet.
#  No surgical history, no really hospitalizations.
#  The pain though isn't really impacting your day-to-day living, day-to-day life.
#  You tried to have a tonal, maltrinate, didn't help.
#  Otherwise, no medications.
#  You've got the family history of your mom with migraines.
#  Otherwise, your family is healthy.
#  You smoke about a half a pack a day.
#  And you don't drink.
#  And then you said you took a trip about a week ago?
#  Yeah.
#  Yeah.
#  Okay.
#  So, if you're going to read it in a week ago?
#  Yeah.
#  I don't know.
#  It was in North Carolina.
#  All right.
#  Yeah.
#  I can understand your concern.
#  About your friends.
#  You said that it was having seizures.
#  I've just never had this kind of pain before.
#  Yeah.
#  I can understand that.
#  So, what I would like to do is...
#  We've pretty much gone over the history.
#  What I'd like to do is complete a physical exam.
#  Okay.
#  Do some testing.
#  All right.
#  And I want to ask two of those.
#  Any other concerns I need to address before we get to the final exam?
#  Okay.
#  That sounds good.
#  Okay.
#  Sounds great.
#  Okay.
#  All right.
#  Hi.
#  I'm Deb.
#  I'm your great standardized patient.
#  Nice job.
#  I'm going to give you some feedback on your communication skills.
#  All right.
#  In this encounter.
#  But before I do, how did you feel it went?
#  I'm pretty good.
#  I was nervous at first.
#  I think.
#  I'm just trying to make sure that I was getting all your education information.
#  So, we could make sure we got the correct tests.
#  Yeah.
#  Yeah.
#  How did you feel when you walked in?
#  You feel pretty comfortable?
#  I think I got more comfortable as we sat down.
#  Yeah.
#  I could see that.
#  Yeah.
#  Good.
#  Okay.
#  Well, I thought you did a nice job.
#  You had an appropriate introduction.
#  You're doing it for yourself or some last name.
#  Sure.
#  Canes.
#  I think you have a very warm demeanor and you're comfortable.
#  Which makes me as a patient comfortable.
#  You did, um, explicit, my chief complaint and asked about any other concerns.
#  And that's when I told you that I was also concerned about my insurance.
#  So, that was another thing on the agenda.
#  So, you did set an mutual agenda.
#  Asked me if I agreed.
#  And so, we had a clear roadmap going forward.
#  So, you did, um, you hit all those real well.
#  You, your first question.
#  Tell me about this pain or, um, that was a nice open-ended question.
#  So, allowed me to then tell my story.
#  Um, followed up with some more, um, pointed questions.
#  Just for clarification.
#  And, um, and you had your an active listener had good contact.
#  Uh, I contact.
#  And, um, could do a little bit more, um, reflective listening, um, just a little
#  point where you could verify, um, check for accuracy of maybe paraphrase.
#  As I'm going through, um, you did a nice summary in the middle.
#  That's good.
#  But just a little bit more reflection on that to let me know as a patient that you're hearing me.
#  Um, you asked my perspective of what I thought was going on.
#  And then you got the story, um, of my fear that we got a brain tumor.
#  Oh, no.
#  Yeah.
#  So, um, I thought you had a nice flow, logical, uh, sequence of questioning.
#  Um, a little bit of sign posting.
#  We just covered this.
#  And now we're going to do that.
#  I heard that once, um, and as these, um, interviews get longer, you're going to want
#  to sign post between each, um, section.
#  I've taken your history.
#  Now I'd like to go into, um, of a physical exam.
#  Okay.
#  I think, um, did a nice summary in the middle.
#  Uh, you moved through quickly.
#  So you attended to, um, the timeline.
#  You did ask permission to ask some, um, uh, social questions.
#  Maybe you want to mention, um, social questions may not be of a flag for me that this is,
#  that's could be personal or uncomfortable.
#  Maybe I'm going to ask a little more of some personal questions here.
#  Is that all right with you?
#  Just so I'm sort of a question.
#  Sounds fine.
#  Me and tell you start asking something that might sound personal.
#  So you might use the, the word, uh, some more personal.
#  Okay.
#  Perfect.
#  Questions here.
#  Uh, not non-judgmental.
#  Didn't, you know, didn't bat an eye when, when I said, I smoke half a pack.
#  Um, you have nice, uh, vocal range.
#  I contact, uh, comfortable demeanor.
#  So, uh, that, um, felt real good.
#  And then, um, you, uh, did a summary, uh, at the end.
#  And, um, asked, did you ask, do anything else?
#  Okay.
#  So anything else before, um, we do a physical exam.
#  So it was very nice, nice encounter.
#  Well, thank you so much.
#  Uh-huh.
#  Nice meeting you.
#  You too.
#  Okay.
# Man, what's that with me?
# Yes.
# Hi.
# Here's, I'll be your doctor today.
# I'm going to just wash my hands really quick.
# Would you perform this stone here?
# Oh, you can.
# Pat's fine.
# Great.
# Well, it's nice to meet you.
# Can you tell me why you're here today?
# I have a terrible headache.
# It looks really bad.
# Is there anything else besides your headache that you want to address here
# today at the clinical point?
# No.
# It's just that.
# Except I am concerned.
# I just recently changed insurance companies and I'm not sure this is going
# to be covered yet.
# What we can do is, well, we're talking and I'm doing your history
# and physical.
# I will have my office secretary look and do the insurance
# plane that you're gas.
# So you don't have to worry about that.
# That sounds good.
# Okay.
# Sounds great.
# Anything else?
# No.
# I just, this is just really bad.
# Okay.
# So what I'd like to do today, and let's take a look at what's causing
# your headache.
# All right.
# I will go over history, physical.
# And then we'll do our physical exam.
# And then we will look into your insurance policy and make sure that's all.
# Okay.
# You know, 10 cares.
# That sounds good.
# Yeah.
# That's good.
# Perfect.
# So tell me a little bit more about this.
# The head pain that you're having.
# Well, it started about three days ago and nothing has helped.
# It's, it's just laid me flat.
# I haven't been able to go to work.
# It's, um, nothing's helped.
# I, um, it's, it's all over.
# Um, I, it really bad when I move.
# So I'm trying not to move too much.
# And the light is bothering me a lot.
# Okay.
# Um, and then, fortunately, I can't dim the lights in this room.
# Okay.
# But it's okay.
# I'll try to go quickly and, um, we'd be okay if I took some notes.
# Sure.
# All right.
# So you said this headache started about three days ago.
# Okay.
# Um, was there any, um, anything that brought about anything unusual?
# What happened maybe three days ago?
# Really?
# No.
# Okay.
# Um, can you tell me anything that makes it better?
# There's no nothings made it better.
# I took some Tylenol and tried to moatrin, nothing.
# Um, I just try not to move too much.
# All right.
# Um, was there anything that makes it worse?
# Yeah.
# Like movement and light.
# Okay.
# And, um, it's just constant though.
# There's, you know, it doesn't, it's just constant.
# It's, it's all over.
# Okay.
# Um, so if you had to rate a pain scale, um, zero being no pain,
# ten being the worst pain you ever had.
# Yeah.
# It's a ten.
# I've never had a headache like this.
# Okay.
# Yeah.
# That sounds really bad.
# Um, now as far as radiation does it move?
# Does it, you said the head, the pain is all up there for your head?
# It's kind of all over.
# Okay.
# Um, but it also, I've got this shooting pain down my neck.
# And my neck is, is very stiff.
# Okay.
# Um, but you need to not, it's, it's, it's the entire head.
# Okay.
# Yeah.
# Um, as far as in the, in the timing, you said that started three days ago, but you said
# it's a constant.
# Yeah.
# It, it, it, it started gradually, but once, once it got there, it's, it hasn't gone away.
# It doesn't get better.
# It doesn't get worse.
# It's just the same.
# Okay.
# Um, so do you, yeah.
# What I want to get is your perception of what you think is going on.
# Oh, I don't know.
# I just, I can hardly think it's so painful.
# I, I just, um, because it's so bad.
# I was afraid, um, my neighbor, um, had a headache and ignored it last year.
# And, uh, suddenly started having seizures and it turns out he had a, um, a brain tumor.
# So I thought, I, I just should come in and, you know, I can understand your
# concern.
# Um, what, how is it impacting your daily life?
# I can't go to work.
# Okay.
# I can't do anything.
# Yeah.
# Okay.
# So it sounds like it's really impacting your life.
# Yeah.
# Yeah.
# Okay.
# Um, if it's okay, I would like to go some talk about a little bit about your medical
# history or social history.
# All right.
# Um, can you tell me as first your medical history, have, do you have any medical conditions
# I should be aware of?
# Um, uh, that not, uh, I was diagnosed with a high blood pressure about three years ago.
# But, uh, we've been addressing it with diet changes since it's controlled.
# It's been monitored?
# Yeah.
# I go in usually I had been just in it's been well controlled.
# So, okay.
# I haven't been on medication for that other than that.
# I haven't had any problems.
# Okay, any surgical history in the hospitalizations?
# No.
# All right.
# And you said you're only medicine you're taking was the talent
# of all trades.
# Yeah, and they didn't help.
# Yeah, okay.
# I just wanted to verify.
# Do you have any drug allergies?
# No.
# No.
# Okay.
# What about family history?
# Do you have any medical history of headaches or...
# In my family?
# Right.
# Oh, you know, my mom said she used to get my green
# and when she was in her 20s and 30s.
# Okay.
# But I don't remember her saying anything else about it.
# My sister, I've one sister.
# She's healthy.
# My dad, he has a high blood pressure
# rather than that.
# He's healthy.
# That's about it.
# I don't have any kit.
# All right.
# It's all right.
# I would like to ask you some social history questions
# that just for the records.
# Do you smoke?
# Yeah, I do.
# Is it cigarettes or children?
# Yes, it's okay.
# How much do you smoke?
# About a half a pack a day.
# Okay.
# What about alcohol?
# I don't drink.
# Okay.
# Also, are you married?
# Yeah, I'm married.
# Okay.
# And children?
# No.
# Okay.
# And just some just some additional questions is...
# Looking at kind of G. Wayne history,
# are you last menstrual period?
# Oh, I'm in a menopause.
# Okay.
# So, going back into the history again, have you...
# You said your mom had migraines earlier on.
# Have you been around and you know other...
# You haven't been nauseous or have you been...
# Yeah, I've been nauseous.
# Okay.
# That night, I threw up twice early on.
# Okay.
# Because when I move, it makes me nauseous.
# Okay.
# Nothing of the ordinary or the past couple weeks have you been on any trips or anything?
# Or...
# Actually, a week ago I was in North Carolina for a family reunion.
# Okay.
# And there was a four-year-old who was sick there.
# I don't know what they had.
# But I guess they ended up taking into emergency.
# So, let me just...
# So, Marisa, make sure I've got everything straight so far.
# You started in the onset of a severe headache about three days ago.
# It's worse with movement.
# Yeah.
# Light really makes a hurt bad.
# It's a 10 out of 10 pain.
# And you're also complaining of a stiff neck with that.
# Yes.
# It came on gradually.
# It's been constant pain in the frontal area.
# Medical history here in Hayper.
# You have high blood pressure, but that's control of the diet.
# No surgical history, no really hospitalizations.
# The pain though isn't really impacting your day-to-day living, day-to-day life.
# You tried to have a tonal, maltrinate, didn't help.
# Otherwise, no medications.
# You've got the family history of your mom with migraines.
# Otherwise, your family is healthy.
# You smoke about a half a pack a day.
# And you don't drink.
# And then you said you took a trip about a week ago?
# Yeah.
# Yeah.
# Okay.
# So, if you're going to read it in a week ago?
# Yeah.
# I don't know.
# It was in North Carolina.
# All right.
# Yeah.
# I can understand your concern.
# About your friends.
# You said that it was having seizures.
# I've just never had this kind of pain before.
# Yeah.
# I can understand that.
# So, what I would like to do is...
# We've pretty much gone over the history.
# What I'd like to do is complete a physical exam.
# Okay.
# Do some testing.
# All right.
# And I want to ask two of those.
# Any other concerns I need to address before we get to the final exam?
# Okay.
# That sounds good.
# Okay.
# Sounds great.
# Okay.
# All right.
# Hi.
# I'm Deb.
# I'm your great standardized patient.
# Nice job.
# I'm going to give you some feedback on your communication skills.
# All right.
# In this encounter.
# But before I do, how did you feel it went?
# I'm pretty good.
# I was nervous at first.
# I think.
# I'm just trying to make sure that I was getting all your education information.
# So, we could make sure we got the correct tests.
# Yeah.
# Yeah.
# How did you feel when you walked in?
# You feel pretty comfortable?
# I think I got more comfortable as we sat down.
# Yeah.
# I could see that.
# Yeah.
# Good.
# Okay.
# Well, I thought you did a nice job.
# You had an appropriate introduction.
# You're doing it for yourself or some last name.
# Sure.
# Canes.
# I think you have a very warm demeanor and you're comfortable.
# Which makes me as a patient comfortable.
# You did, um, explicit, my chief complaint and asked about any other concerns.
# And that's when I told you that I was also concerned about my insurance.
# So, that was another thing on the agenda.
# So, you did set an mutual agenda.
# Asked me if I agreed.
# And so, we had a clear roadmap going forward.
# So, you did, um, you hit all those real well.
# You, your first question.
# Tell me about this pain or, um, that was a nice open-ended question.
# So, allowed me to then tell my story.
# Um, followed up with some more, um, pointed questions.
# Just for clarification.
# And, um, and you had your an active listener had good contact.
# Uh, I contact.
# And, um, could do a little bit more, um, reflective listening, um, just a little
# point where you could verify, um, check for accuracy of maybe paraphrase.
# As I'm going through, um, you did a nice summary in the middle.
# That's good.
# But just a little bit more reflection on that to let me know as a patient that you're hearing me.
# Um, you asked my perspective of what I thought was going on.
# And then you got the story, um, of my fear that we got a brain tumor.
# Oh, no.
# Yeah.
# So, um, I thought you had a nice flow, logical, uh, sequence of questioning.
# Um, a little bit of sign posting.
# We just covered this.
# And now we're going to do that.
# I heard that once, um, and as these, um, interviews get longer, you're going to want
# to sign post between each, um, section.
# I've taken your history.
# Now I'd like to go into, um, of a physical exam.
# Okay.
# I think, um, did a nice summary in the middle.
# Uh, you moved through quickly.
# So you attended to, um, the timeline.
# You did ask permission to ask some, um, uh, social questions.
# Maybe you want to mention, um, social questions may not be of a flag for me that this is,
# that's could be personal or uncomfortable.
# Maybe I'm going to ask a little more of some personal questions here.
# Is that all right with you?
# Just so I'm sort of a question.
# Sounds fine.
# Me and tell you start asking something that might sound personal.
# So you might use the, the word, uh, some more personal.
# Okay.
# Perfect.
# Questions here.
# Uh, not non-judgmental.
# Didn't, you know, didn't bat an eye when, when I said, I smoke half a pack.
# Um, you have nice, uh, vocal range.
# I contact, uh, comfortable demeanor.
# So, uh, that, um, felt real good.
# And then, um, you, uh, did a summary, uh, at the end.
# And, um, asked, did you ask, do anything else?
# Okay.
# So anything else before, um, we do a physical exam.
# So it was very nice, nice encounter.
# Well, thank you so much.
# Uh-huh.
# Nice meeting you.
# You too.
# Okay.

# %%
# Step 3.5 - Speech dirization
# ─── 1) Define your ASR segments ────────────────────────────────────────────────
# time_segments = time_segments


# ─── 2) Load the full waveform once ────────────────────────────────────────────
audio_path = audio_file_path
waveform, sample_rate = torchaudio.load(audio_path)  # waveform: [channels, samples] ... We're also reloading after denoising

# ─── 3) Extract embeddings for each segment ────────────────────────────────────
# Note: The classifier expects a 1D tensor of audio samples, so we need to slice out the segments
MIN_SEGMENT_SEC = 0.5

embeddings = []
for seg in time_segments:
    # 1) Slice out the raw audio samples
    s = int(seg["start"] * sample_rate)
    e = int(seg["end"]   * sample_rate)
    clip = waveform[:, s:e]            # [channels, length]

    # 2) Convert to mono
    clip = clip.mean(dim=0)            # [length]

    # 3) Zero‑pad to a minimum length
    min_len = int(MIN_SEGMENT_SEC * sample_rate)
    if clip.shape[0] < min_len:
        padding = min_len - clip.shape[0]
        clip = torch.cat([clip, torch.zeros(padding)], dim=0)

    # 4) Now clip is a 1D tensor [time]. encode_batch will accept that.
    with torch.no_grad():
        emb = speech_dairization_classifier.encode_batch(clip)  # → [1, emb_dim]
    embeddings.append(emb[0].cpu().numpy())

embeddings = np.vstack(embeddings)

# ─── 4) Cluster embeddings into speakers ───────────────────────────────────────
n_speakers = 2  # adjust as needed
clustering = AgglomerativeClustering(n_clusters=n_speakers).fit(embeddings)
labels = clustering.labels_                               # array of length n_segments

# Assign speaker labels back into each segment
for seg, label in zip(segments, labels):
    seg["speaker"] = f"SPEAKER {label+1}"

# ─── 5) Merge consecutive segments with the same speaker ───────────────────────
merged = []
for seg in segments:
    if not merged or merged[-1]["speaker"] != seg["speaker"]:
        merged.append({
            "start":   seg["start"],
            "end":     seg["end"],
            "speaker": seg["speaker"],
            "text":    seg["text"].strip()
        })
    else:
        # extend the end and append text
        merged[-1]["end"] = seg["end"]
        merged[-1]["text"] += " " + seg["text"].strip()

# ─── 6) Write out a diarized transcript ────────────────────────────────────────
with open("output_transcripts/diarized_transcript.txt", "w", encoding="utf-8") as f:
    for seg in merged:
        ts = str(datetime.timedelta(seconds=int(seg["start"])))
        print(f"{seg['speaker']} [{ts}]: {seg['text']}\n")
        f.write(f"{seg['speaker']} [{ts}]: {seg['text']}\n")

print("Diarized transcript saved to diarized_transcript.txt")

# %%
# Step 4 - Text Classification

def classify_sentence(sentence):
    inputs = text_classification_tokenizer(sentence, return_tensors="pt", truncation=True, padding="max_length", max_length=128)
    outputs = text_classification_model(**inputs)
    logits = outputs.logits
    probabilities = torch.softmax(logits, dim=1).detach().cpu().numpy()[0]
    predicted_class = int(probabilities.argmax())
    return predicted_class, probabilities


for sentence in transcript:
    # Test on a new sentence
    pred_class, probs = classify_sentence(sentence)

    # Print the results
    labels = ["SmallTalk", "Demographics", "Treatment_Plan", "Past_Medical_History", "Active_Symptoms", "Test_Results", "Allergies", "Current_Conditions", "Clinical_Diagnosis", "Family_History"]
    print(f"Predicted class: {pred_class}, {labels[pred_class]}")
    print("Probabilities:", probs)
# Out:
# Predicted class: 0, SmallTalk
# Probabilities: [0.13090172 0.09876203 0.10390221 0.09583224 0.10224502 0.11178298
#  0.10571308 0.08255803 0.07861784 0.08968489]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10566767 0.10061268 0.10676946 0.10046227 0.10353696 0.09325973
#  0.09458303 0.10341836 0.09207452 0.09961524]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11987253 0.10713323 0.09753264 0.10259789 0.09405783 0.09491007
#  0.09925766 0.11460137 0.08514669 0.08489002]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11987253 0.10713323 0.09753264 0.10259789 0.09405783 0.09491007
#  0.09925766 0.11460137 0.08514669 0.08489002]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10522985 0.10778552 0.11514554 0.10603891 0.09005572 0.09456833
#  0.10171968 0.09059181 0.09912257 0.08974206]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12198736 0.11184551 0.11605623 0.11015683 0.09088215 0.09277256
#  0.09074153 0.08857068 0.08006139 0.09692577]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11835276 0.09111791 0.10595234 0.08753601 0.10708033 0.11799585
#  0.10764565 0.10140657 0.07603229 0.08688024]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11835276 0.09111791 0.10595234 0.08753601 0.10708033 0.11799585
#  0.10764565 0.10140657 0.07603229 0.08688024]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10566767 0.10061268 0.10676946 0.10046227 0.10353696 0.09325973
#  0.09458303 0.10341836 0.09207452 0.09961524]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12376303 0.1067476  0.11588689 0.09478696 0.10825109 0.09900972
#  0.09793338 0.0984081  0.07668898 0.07852413]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 1, Demographics
# Probabilities: [0.10487051 0.11285517 0.09723446 0.09450532 0.09800476 0.10845441
#  0.09990263 0.10617298 0.0879066  0.09009328]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12512644 0.0980597  0.10866115 0.10391328 0.09422666 0.09595829
#  0.08774715 0.10971627 0.08158371 0.0950074 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12512644 0.0980597  0.10866115 0.10391328 0.09422666 0.09595829
#  0.08774715 0.10971627 0.08158371 0.0950074 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12376303 0.1067476  0.11588689 0.09478696 0.10825109 0.09900972
#  0.09793338 0.0984081  0.07668898 0.07852413]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.1162173  0.09370921 0.09202787 0.10878113 0.09259448 0.12297518
#  0.09315392 0.10913493 0.0749153  0.09649076]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 5, Test_Results
# Probabilities: [0.1162173  0.09370921 0.09202787 0.10878113 0.09259448 0.12297518
#  0.09315392 0.10913493 0.0749153  0.09649076]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12445069 0.09967451 0.11329119 0.10706415 0.09891304 0.10185792
#  0.07311136 0.10529952 0.08384562 0.09249195]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11987253 0.10713323 0.09753264 0.10259789 0.09405783 0.09491007
#  0.09925766 0.11460137 0.08514669 0.08489002]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12512644 0.0980597  0.10866115 0.10391328 0.09422666 0.09595829
#  0.08774715 0.10971627 0.08158371 0.0950074 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.11130768 0.0949336  0.09654361 0.10854109 0.10568453 0.11350343
#  0.0879121  0.10456587 0.0906822  0.0863259 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 5, Test_Results
# Probabilities: [0.09986158 0.09978868 0.10259344 0.08944755 0.09999048 0.12258897
#  0.08776242 0.1168988  0.08529022 0.09577783]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.125064   0.10931382 0.10532219 0.09265485 0.10199073 0.10567896
#  0.10204125 0.10726509 0.07093143 0.07973766]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12512644 0.0980597  0.10866115 0.10391328 0.09422666 0.09595829
#  0.08774715 0.10971627 0.08158371 0.0950074 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12803254 0.11090445 0.09804307 0.11036336 0.08770831 0.0927797
#  0.08366127 0.10682336 0.08647329 0.09521072]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12053146 0.10971741 0.09291926 0.10628466 0.08770902 0.10324555
#  0.09469946 0.10894763 0.08509361 0.09085185]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10522985 0.10778552 0.11514554 0.10603891 0.09005572 0.09456833
#  0.10171968 0.09059181 0.09912257 0.08974206]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.10504984 0.08979285 0.10744815 0.08832815 0.13040034 0.11811379
#  0.10165689 0.09451932 0.07409952 0.09059115]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10566767 0.10061268 0.10676946 0.10046227 0.10353696 0.09325973
#  0.09458303 0.10341836 0.09207452 0.09961524]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.13081162 0.09708277 0.11104187 0.09941111 0.09514356 0.11255408
#  0.09720612 0.09454109 0.07630033 0.08590747]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12053146 0.10971741 0.09291926 0.10628466 0.08770902 0.10324555
#  0.09469946 0.10894763 0.08509361 0.09085185]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.11633912 0.08674231 0.09973973 0.10397272 0.10400283 0.11820023
#  0.09383871 0.10563229 0.07150879 0.10002327]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.125064   0.10931382 0.10532219 0.09265485 0.10199073 0.10567896
#  0.10204125 0.10726509 0.07093143 0.07973766]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10566767 0.10061268 0.10676946 0.10046227 0.10353696 0.09325973
#  0.09458303 0.10341836 0.09207452 0.09961524]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12178565 0.09313762 0.10609802 0.09828387 0.10326602 0.11095281
#  0.09384397 0.10979144 0.0748831  0.08795747]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11987253 0.10713323 0.09753264 0.10259789 0.09405783 0.09491007
#  0.09925766 0.11460137 0.08514669 0.08489002]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.11394647 0.09893088 0.10620872 0.10318729 0.11501722 0.09003068
#  0.10536663 0.09030154 0.08992843 0.08708224]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12512644 0.0980597  0.10866115 0.10391328 0.09422666 0.09595829
#  0.08774715 0.10971627 0.08158371 0.0950074 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10522985 0.10778552 0.11514554 0.10603891 0.09005572 0.09456833
#  0.10171968 0.09059181 0.09912257 0.08974206]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12376303 0.1067476  0.11588689 0.09478696 0.10825109 0.09900972
#  0.09793338 0.0984081  0.07668898 0.07852413]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.1007301  0.10445638 0.10643551 0.0991345  0.09494784 0.10528186
#  0.10195369 0.10432757 0.09431347 0.08841902]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 1, Demographics
# Probabilities: [0.10487051 0.11285517 0.09723446 0.09450532 0.09800476 0.10845441
#  0.09990263 0.10617298 0.0879066  0.09009328]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12512644 0.0980597  0.10866115 0.10391328 0.09422666 0.09595829
#  0.08774715 0.10971627 0.08158371 0.0950074 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12376303 0.1067476  0.11588689 0.09478696 0.10825109 0.09900972
#  0.09793338 0.0984081  0.07668898 0.07852413]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 5, Test_Results
# Probabilities: [0.09986158 0.09978868 0.10259344 0.08944755 0.09999048 0.12258897
#  0.08776242 0.1168988  0.08529022 0.09577783]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 1, Demographics
# Probabilities: [0.10487051 0.11285517 0.09723446 0.09450532 0.09800476 0.10845441
#  0.09990263 0.10617298 0.0879066  0.09009328]
# Predicted class: 1, Demographics
# ...
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11987253 0.10713323 0.09753264 0.10259789 0.09405783 0.09491007
#  0.09925766 0.11460137 0.08514669 0.08489002]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.1007301  0.10445638 0.10643551 0.0991345  0.09494784 0.10528186
#  0.10195369 0.10432757 0.09431347 0.08841902]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10566767 0.10061268 0.10676946 0.10046227 0.10353696 0.09325973
#  0.09458303 0.10341836 0.09207452 0.09961524]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10117377 0.10784101 0.10753313 0.09405795 0.09760807 0.11737306
#  0.08675368 0.10571161 0.092236   0.08971176]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.125064   0.10931382 0.10532219 0.09265485 0.10199073 0.10567896
#  0.10204125 0.10726509 0.07093143 0.07973766]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.1026058  0.09966138 0.10545766 0.09523139 0.0936417  0.10901591
#  0.09353531 0.11147203 0.09323592 0.09614293]
# Predicted class: 2, Treatment_Plan
# Probabilities: [0.10566767 0.10061268 0.10676946 0.10046227 0.10353696 0.09325973
#  0.09458303 0.10341836 0.09207452 0.09961524]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 5, Test_Results
# Probabilities: [0.09986158 0.09978868 0.10259344 0.08944755 0.09999048 0.12258897
#  0.08776242 0.1168988  0.08529022 0.09577783]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12210107 0.10492538 0.10061491 0.10787284 0.09477066 0.09441342
#  0.09009563 0.1007902  0.08385164 0.1005642 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.10145291 0.08935358 0.10368602 0.08873766 0.11958309 0.11816274
#  0.10690014 0.11200707 0.07770495 0.0824118 ]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 6, Allergies
# Probabilities: [0.10408977 0.09131041 0.10609792 0.11079541 0.1020314  0.08835632
#  0.11221034 0.09980574 0.09043021 0.09487244]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 5, Test_Results
# Probabilities: [0.10135566 0.10051397 0.09645753 0.09785275 0.10303614 0.11469205
#  0.09395752 0.10518502 0.09457923 0.09237013]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 5, Test_Results
# Probabilities: [0.10920478 0.0812488  0.11262662 0.09911086 0.11117554 0.11721467
#  0.1010003  0.09993383 0.07278116 0.09570328]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.11165792 0.10826783 0.10205973 0.09946662 0.09653724 0.09522331
#  0.09064873 0.11821369 0.08625676 0.09166821]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12394401 0.11162927 0.10267998 0.10343482 0.09123188 0.11399759
#  0.08119225 0.09841546 0.08697924 0.08649551]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12023446 0.10381015 0.10193946 0.09310587 0.09371375 0.10440468
#  0.08848244 0.10971942 0.09004769 0.0945421 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11916529 0.10329438 0.10948116 0.10884939 0.095688   0.09890289
#  0.08526083 0.10707565 0.0848823  0.08740009]
# Predicted class: 5, Test_Results
# Probabilities: [0.11080374 0.09703148 0.10954341 0.09616452 0.09705445 0.11478363
#  0.09523308 0.0994366  0.08761609 0.09233303]
# Predicted class: 5, Test_Results
# Probabilities: [0.1162173  0.09370921 0.09202787 0.10878113 0.09259448 0.12297518
#  0.09315392 0.10913493 0.0749153  0.09649076]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12198736 0.11184551 0.11605623 0.11015683 0.09088215 0.09277256
#  0.09074153 0.08857068 0.08006139 0.09692577]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10763596 0.10401816 0.09423839 0.10044641 0.0997757  0.09958615
#  0.10054442 0.12058176 0.08695997 0.08621305]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 0, SmallTalk
# Probabilities: [0.12278416 0.09864835 0.10181723 0.0982372  0.09453829 0.10190545
#  0.09956574 0.1033686  0.08630583 0.0928291 ]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 0, SmallTalk
# Probabilities: [0.11797061 0.0986097  0.1048439  0.10142318 0.10562897 0.10003542
#  0.08761375 0.1052792  0.08162625 0.09696898]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]
# Predicted class: 4, Active_Symptoms
# Probabilities: [0.10504984 0.08979285 0.10744815 0.08832815 0.13040034 0.11811379
#  0.10165689 0.09451932 0.07409952 0.09059115]
# Predicted class: 5, Test_Results
# Probabilities: [0.09986158 0.09978868 0.10259344 0.08944755 0.09999048 0.12258897
#  0.08776242 0.1168988  0.08529022 0.09577783]
# Predicted class: 1, Demographics
# Probabilities: [0.10985983 0.11362945 0.1015994  0.09502721 0.0999129  0.09536203
#  0.08948737 0.10450061 0.09410802 0.09651329]
# Predicted class: 3, Past_Medical_History
# Probabilities: [0.11692573 0.11707509 0.10772352 0.11918938 0.0895875  0.08530438
#  0.09009954 0.09499579 0.08438886 0.09471014]
# Predicted class: 0, SmallTalk
# Probabilities: [0.10827024 0.10094195 0.10449703 0.09903635 0.10537083 0.09374253
#  0.09602687 0.10063004 0.09694359 0.09454057]
# Predicted class: 7, Current_Conditions
# Probabilities: [0.10457605 0.10233615 0.09776613 0.09844018 0.10262644 0.10361329
#  0.08058926 0.11140728 0.10380062 0.09484458]

# %%
# step 5 - Context Grouping and input correction

args = TTSettings(num_beams=5, min_length=1)

for sentence in transcript:
    # Add the prefix "grammar: " before each input 
    result = grammar_correction_model.generate_text(f"grammar: {sentence}", args=args)
    print(result.text)

# %%
# step 6 - Entity extraction

for i, text in enumerate(transcript, 1):
    print(f"\nExample {i}: {text}")
    doc = entity_extraction_model(text)
    for ent in doc.ents:
        print(f"  {ent.text}: {ent.label_}")
